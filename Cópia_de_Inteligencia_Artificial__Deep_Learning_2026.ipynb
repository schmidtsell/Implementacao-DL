# %% [markdown]
# <a href="https://colab.research.google.com/github/schmidtsell/Implementacao-DL/blob/main/C%C3%B3pia_de_Inteligencia_Artificial__Deep_Learning_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![logo](https://drive.google.com/uc?id=1T8A0J3QupfNWPi0BbgYPzl4E2JAi-X1V)
#
# # Demonstração de implementações de Inteligência Artificial com Deep Learning
#
# ** **
#
# Bem-vindo a este notebook dedicado à exploração prática dos principais conceitos de inteligência artificial, com foco especial no campo do Deep Learning.
#
# Aqui, você terá a oportunidade de mergulhar de forma hands-on em uma jornada de descoberta que abrange os princípios fundamentais. A inteligência artificial tem revolucionado a maneira como interagimos com tecnologia e dados. Ao longo deste notebook, mostraremos como implementarmos algoritmos de aprendizado de máquina e redes neurais profundas.
#
# O objetivo é fornecer o ponta pé inicial para a implementação de algoritmos de inteligência artificial, ao mesmo tempo em que promovemos a capacidade de criar soluções de IA do zero.

# %% [markdown]
# ## 1. Principais Bibliotecas
#
# A documentação oficial do Python inclui informações sobre os módulos e bibliotecas padrão do Python. É um ótimo recurso para entender as bibliotecas que fazem parte da biblioteca padrão do Python (https://docs.python.org/).
#
#
# O PyPI é o repositório oficial de pacotes Python. Você pode pesquisar pacotes aqui por nome ou palavra-chave. Também é o local onde você pode encontrar informações detalhadas sobre cada pacote, incluindo documentação e links para o código-fonte (https://pypi.org/).

# %% [markdown]
# ![numpy](https://drive.google.com/uc?id=1zCoc6jtzd2oMymSSWncAuU9RizGIzNVT)
#
# NumPy é uma biblioteca fundamental para computação científica em Python. Ela fornece suporte para arrays multidimensionais, funções matemáticas para manipulação de dados e operações de álgebra linear. É amplamente usada para preparar dados antes de treinar modelos de IA.
#
# O exemplo abaixo realizamos operações básicas de matemática (soma, subtração, multiplicação e divisão) com dois arrays.

# %%
import numpy as np

# Criando dois arrays NumPy
array1 = np.array([10, 20, 30, 40, 50])
array2 = np.array([1, 2, 5, 10, 20])

# Exibindo os arrays
print("Array 1:")
print(array1)

print("\nArray 2:")
print(array2)

# Realizando as operações com os arrays
soma = array1 + array2
subtracao = array1 - array2
multiplicacao = array1 * array2
divisao = array1 / array2

# Exibindo os resultados das operações
print("\nSoma:")
print(soma)

print("\nSubtração:")
print(subtracao)

print("\nMultiplicação:")
print(multiplicacao)

print("\nDivisão:")
print(divisao)
# Out:
# Array 1:
# [10 20 30 40 50]
#
# Array 2:
# [ 1  2  5 10 20]
#
# Soma:
# [11 22 35 50 70]
#
# Subtração:
# [ 9 18 25 30 30]
#
# Multiplicação:
# [  10   40  150  400 1000]
#
# Divisão:
# [10.  10.   6.   4.   2.5]

# %% [markdown]
# ![pandas](https://drive.google.com/uc?id=1QqfVESnzP_wqEHSl_k4MBWCMK6pPxy4Z)
#
# Pandas é uma biblioteca que oferece estruturas de dados flexíveis para análise de dados, como DataFrames. Ela é crucial para a manipulação e análise de dados, facilitando a limpeza e a transformação de dados para treinamento de modelos.
#
# O exemplo abaixo mostra a criação de um DataFrame a partir de uma estrutura de arrays. O DataFrame é a estrutura de manipulação de dados mais importante do Pandas.

# %%
import pandas as pd

# Criar um dicionário com os dados dos alunos
dados_alunos = {
    'Nome': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Idade': [20, 21, 22, 19, 20],
    'Nota': [85, 92, 78, 95, 88]
}

# Criar um DataFrame a partir do dicionário
df_alunos = pd.DataFrame(dados_alunos)

# Exibir o DataFrame
df_alunos
# Out:
#       Nome  Idade  Nota
# 0    Alice     20    85
# 1      Bob     21    92
# 2  Charlie     22    78
# 3    David     19    95
# 4      Eve     20    88

# %% [markdown]
# ![matplotlib](https://drive.google.com/uc?id=1OWGDaXUDDXM9yG36_TFAZGVXpfrdB13w)
#
# Matplotlib é usada para criação de gráficos e visualização de dados. Visualização é uma parte importante do processo de IA, pois ajuda a entender os dados e os resultados dos modelos.
#
# No exemplo abaixo, usamos dados de vendas mensais em milhares de dólares para criar um gráfico de barras que representa o desempenho de vendas ao longo do ano de 2023.

# %%
import matplotlib.pyplot as plt

# Dados de vendas mensais em milhares de dólares
meses = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro']
vendas_mensais = [120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340]

# Criar um gráfico de barras
plt.bar(meses, vendas_mensais, color='royalblue')

# Adicionar rótulos aos eixos e um título
plt.xlabel('Mês')
plt.ylabel('Vendas Mensais (em milhares de dólares)')
plt.title('Desempenho de Vendas Mensais em 2023')

# Rotacionar os rótulos do eixo x para facilitar a leitura
plt.xticks(rotation=45)

# Exibir o gráfico
plt.tight_layout()  # Ajustar layout para evitar corte de rótulos
plt.show()

# %% [markdown]
# ![seaborn](https://drive.google.com/uc?id=1TkyIiwpLPDjolOlw1bfOFCxyfYJAAL_G)
#
# Seaborn também é utilizado para criação de gráficos e visualização de dados. Essa é uma biblioteca construida sobre o Matplotlib e fornece uma interface de alto nível para criar gráficos estilizados com mais facilidade.
#
# Utilizaremos o mesmo exemplo de cima para podermos compararmos os gráficos.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Dados de vendas mensais em milhares de dólares
meses = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro']
vendas_mensais = [120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340]

# Criar um gráfico de barras com Seaborn
sns.set(style="whitegrid")
plt.figure(figsize=(10, 5))  # Define o tamanho da figura

# Use o Seaborn para criar o gráfico de barras
ax = sns.barplot(x=meses, y=vendas_mensais, hue=meses, palette="Blues", legend=False)

# Adicionar rótulos aos eixos e um título
plt.xlabel('Mês')
plt.ylabel('Vendas Mensais (em milhares de dólares)')
plt.title('Desempenho de Vendas Mensais em 2023')

# Rotacionar os rótulos do eixo x para facilitar a leitura
plt.xticks(rotation=45)

# Exibir o gráfico
plt.tight_layout()  # Ajustar layout para evitar corte de rótulos
plt.show()

# %% [markdown]
# ![scikit-learn](https://drive.google.com/uc?id=1ZxpA7l5KU4IMF5VJRAYfl29A9vkkDSlS)
#
# Scikit-learn é uma das bibliotecas mais populares para aprendizado de máquina em Python. Ela oferece uma ampla gama de algoritmos de classificação, regressão, clustering e pré-processamento de dados, além de ferramentas para avaliação de modelos. Principais datasets oferecidos: Iris Dataset, Digits Dataset, Wine Dataset, Breast Cancer Dataset, Boston Housing Dataset, Diabetes Dataset, Linnerud Dataset, Olivetti Faces Dataset, 20 Newsgroups Dataset.
#
# O exemplo abaixo mostra uma implementação que traz alguns detalhes do 20 Newsgroups Dataset.

# %%
from sklearn import datasets

# Carregar o conjunto de dados "20 Newsgroups"
newsgroups = datasets.fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'))

# Listar as categorias disponíveis no conjunto de dados
print("Categorias disponíveis:")
print(newsgroups.target_names)

# Exibir o conteúdo de uma amostra
sample_index = 10
print(f"\nConteúdo da amostra {sample_index} (categoria: {newsgroups.target_names[newsgroups.target[sample_index]]}):\n")
print(newsgroups.data[sample_index])

# Número total de amostras
print(f"\nNúmero total de amostras: {len(newsgroups.data)}")
# Out:
# Categorias disponíveis:
# ['alt.atheism', 'comp.graphics', 'comp.os.ms-windows.misc', 'comp.sys.ibm.pc.hardware', 'comp.sys.mac.hardware', 'comp.windows.x', 'misc.forsale', 'rec.autos', 'rec.motorcycles', 'rec.sport.baseball', 'rec.sport.hockey', 'sci.crypt', 'sci.electronics', 'sci.med', 'sci.space', 'soc.religion.christian', 'talk.politics.guns', 'talk.politics.mideast', 'talk.politics.misc', 'talk.religion.misc']
#
# Conteúdo da amostra 10 (categoria: talk.religion.misc):
#
# the blood of the lamb.
#
# This will be a hard task, because most cultures used most animals
# for blood sacrifices. It has to be something related to our current
# post-modernism state. Hmm, what about used computers?
#
# Cheers,
# Kent
#
# Número total de amostras: 18846

# %% [markdown]
# ![scikit-learn](https://drive.google.com/uc?id=1Lgd-sJ5wUXrVo40RK5OU97r0iuYYnVFI)
#
# Se você estiver interessado em processamento de linguagem natural (NLP), o NLTK é uma biblioteca essencial. Ele oferece recursos para tokenização, análise sintática, classificação de texto e muito mais.
#
# Neste exemplo, estamos usando a função word_tokenize do NLTK para dividir o texto em palavras e a função sent_tokenize para dividir o texto em sentenças. O resultado é uma lista de sentenças e uma lista de palavras tokenizadas que podem ser usadas em várias tarefas de PLN.

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize

# Baixando os modelos de tokenização de sentenças Punkt para que o NLTK possa usá-los
nltk.download('punkt')
nltk.download('punkt_tab') # Adicionado para baixar o recurso 'punkt_tab'

# Texto de exemplo
texto = "O NLTK é uma biblioteca Python para processamento de linguagem natural. Ela fornece muitos recursos úteis para tarefas de processamento de linguagem natural."

# Tokenização de sentenças
sentencas = sent_tokenize(texto)

# Tokenização de palavras
palavras = word_tokenize(texto)

# Exibir as sentenças e palavras tokenizadas
print("Sentenças tokenizadas:")
for sentenca in sentencas:
    print(sentenca)

print("\nPalavras tokenizadas:")
for palavra in palavras:
    print(palavra)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Sentenças tokenizadas:
# O NLTK é uma biblioteca Python para processamento de linguagem natural.
# Ela fornece muitos recursos úteis para tarefas de processamento de linguagem natural.
#
# Palavras tokenizadas:
# O
# NLTK
# é
# uma
# biblioteca
# Python
# para
# processamento
# de
# linguagem
# natural
# .
# Ela
# fornece
# muitos
# recursos
# úteis
# para
# tarefas
# de
# processamento
# de
# linguagem
# natural
# .
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %% [markdown]
# # 2. Introdução à Machine Learning (Classificação)
#
# Os algoritmos de classificação são uma categoria fundamental de técnicas de aprendizado de máquina. Eles têm o propósito de atribuir rótulos ou categorias a dados com base em suas características. Esses algoritmos desempenham um papel crucial em uma ampla gama de aplicações, desde filtragem de spam de e-mails até análise de sentimentos em redes sociais e diagnóstico médico.
#
# Alguns dos principais algoritmos de classificação são:
#
# - **Naive Bayes:** Este é um algoritmo probabilístico que se baseia no Teorema de Bayes. É amplamente utilizado em classificação de textos, detecção de spam de e-mails e análise de sentimentos.
#
# - **Regressão Logística:** Embora seja frequentemente usado para problemas de regressão, a regressão logística também é uma escolha popular para classificação binária. Ela modela a probabilidade de um exemplo pertencer a uma classe.
#
# - **Árvores de Decisão:** As árvores de decisão dividem o conjunto de dados em subconjuntos menores com base em regras de decisão. São fáceis de interpretar, mas podem ser suscetíveis a overfitting.
#
# - **Random Forest:** Uma extensão das árvores de decisão, o Random Forest constrói várias árvores e faz a média ou votação de suas previsões para obter uma classificação final. Isso ajuda a reduzir o overfitting.
#
# - **Support Vector Machines (SVM):** O SVM é eficaz em problemas de classificação binária. Ele encontra um hiperplano que melhor separa as classes no espaço de características.
#
# - **k-Nearest Neighbors (k-NN):** O k-NN classifica exemplos com base na classe predominante entre seus k vizinhos mais próximos no espaço de características.
#
# - **Redes Neurais Artificiais:** Redes neurais profundas (Deep Learning), redes neurais convolucionais (CNN) e redes neurais recorrentes (RNN), têm sido usadas com sucesso em tarefas de classificação, especialmente em visão computacional e processamento de linguagem natural.
#
# Para um melhor entendimento vamos implementar um classificador de mensagens de texto em categorias de sentimento, como "gostei" ou "não gostei". Imagine um cenário em que você deseja automatizar a análise de sentimentos em mensagens de clientes para avaliar a satisfação do cliente ou monitorar a opinião pública sobre um produto ou serviço. É exatamente isso que faremos aqui.
#
# ![ciclo](https://drive.google.com/uc?id=1SEPlrt2CMvl0c-vlB_ECDF8ADp34Nm_2)
#
#
# Para isso vamos seguir as seguintes etapas: pré-processamento, treinamento, avaliação.

# %% [markdown]
# ### 2.1 Pré-processamento (preparação dos dados)
#
# Nessa etapa estamos basicamente dividindo o dataframe para treinamento (70%) e para teste (30%).

# %%
# Importa a biblioteca pandas para manipulação de dados tabulares.
import pandas as pd

# Importa a função train_test_split para dividir os dados em conjuntos de treinamento e teste.
from sklearn.model_selection import train_test_split

# Define os dados como uma lista de tuplas, onde cada tupla contém uma frase e seu sentimento correspondente.
data = [
    ('Eu amo passar tempo com minha família', 'gostei'),
    ('Aprender novas habilidades é ótimo', 'gostei'),
    ('O dia está ensolarado e maravilhoso', 'gostei'),
    ('Estou tão feliz com os resultados', 'gostei'),
    ('Adoro quando as coisas dão certo', 'gostei'),
    ('Cometi um erro, estou me sentindo mal', 'não gostei'),
    ('Fiquei preso no trânsito, que chatice', 'não gostei'),
    ('Meu computador quebrou, que desastre', 'não gostei'),
    ('Estou doente e me sinto terrível', 'não gostei'),
    ('Perdi meu emprego, estou arrasado', 'não gostei'),
    ('A comida estava deliciosa no restaurante', 'gostei'),
    ('O atendimento foi péssimo no restaurante', 'não gostei'),
    ('Recebi um elogio hoje, me sinto bem', 'gostei'),
    ('Que filme emocionante, chorei muito', 'gostei'),
    ('Perdi o ônibus e cheguei atrasado', 'não gostei'),
    ('Estou ansioso para a viagem de férias', 'gostei'),
    ('Tive um pesadelo assustador', 'não gostei'),
    ('O livro que estou lendo é incrível', 'gostei'),
    ('Discussão com o chefe no trabalho', 'não gostei'),
    ('Estou orgulhoso das minhas realizações', 'gostei'),
    ('Meu time ganhou o jogo, estou feliz', 'gostei'),
    ('Não consegui resolver esse problema', 'não gostei'),
    ('Recebi uma promoção no trabalho', 'gostei'),
    ('Cometi um erro grave, estou envergonhado', 'não gostei'),
    ('Meu aniversário está chegando, estou animado', 'gostei'),
    ('Perdi meu voo, estou frustrado', 'não gostei'),
    ('O pôr do sol na praia é incrível', 'gostei'),
    ('Minha internet está lenta, que irritação', 'não gostei'),
    ('Ganhei um prêmio, estou radiante', 'gostei'),
    ('A chuva estragou meu passeio', 'não gostei'),
    ('Minha comida favorita para o jantar', 'gostei'),
    ('Briguei com um amigo, estou triste', 'não gostei'),
    ('Feriado chegando, mal posso esperar', 'gostei'),
    ('Meu carro quebrou na estrada', 'não gostei'),
    ('O concerto da banda foi incrível', 'gostei'),
    ('Meu vizinho faz muito barulho', 'não gostei'),
    ('Realizei um sonho, estou emocionado', 'gostei'),
    ('Não consegui encontrar minhas chaves', 'não gostei'),
    ('Passei no exame, estou aliviado', 'gostei'),
    ('Perdi meu celular, que desespero', 'não gostei'),
    ('Meu time perdeu, estou decepcionado', 'não gostei'),
    ('O parque estava lotado, que bagunça', 'não gostei'),
    ('Recebi um elogio no trabalho', 'gostei'),
    ('Meu filho tirou notas altas na escola', 'gostei'),
    ('Esqueci meu guarda-chuva, fiquei molhado', 'não gostei'),
    ('Fiz um novo amigo hoje, estou contente', 'gostei'),
    ('Estou com gripe, me sinto péssimo', 'não gostei'),
    ('Comemorei meu aniversário com amigos', 'gostei'),
    ('A viagem foi incrível, conheci lugares novos', 'gostei'),
    ('Briguei com meu irmão, estou chateado', 'não gostei')
]

# Cria um DataFrame do pandas com os dados, onde cada linha contém uma frase e um sentimento.
df = pd.DataFrame(data, columns=['Frase', 'Sentimento'])

# Divide os dados em conjuntos de treinamento e teste. Neste caso, 70% dos dados são usados para treinamento e 30% para teste.
train_df, test_df = train_test_split(df, test_size=0.3, random_state=42)

print('Dataframe de treinamento: ', train_df.shape)
print('Dataframe de teste: ', test_df.shape)
# Out:
# Dataframe de treinamento:  (35, 2)
# Dataframe de teste:  (15, 2)

# %%
import matplotlib.pyplot as plt

# Agrupa e conta o número de ocorrências de cada sentimento no DataFrame de treinamento.
sentiment_counts = df['Sentimento'].value_counts()

# Agrupa e conta o número de ocorrências de cada sentimento no DataFrame de treinamento.
train_sentiment_counts = train_df['Sentimento'].value_counts()

# Agrupa e conta o número de ocorrências de cada sentimento no DataFrame de teste.
test_sentiment_counts = test_df['Sentimento'].value_counts()

# Cria uma figura com trê subplots (um para total, outro para treinamento e outro para teste).
fig, axs = plt.subplots(1, 3, figsize=(12, 3))

# Gráfico de barra para o DataFrame total.
axs[0].bar(sentiment_counts.index, sentiment_counts.values, color=['royalblue','indianred'])
axs[0].set_title('Distribuição de Sentimentos (Total)')
axs[0].set_xlabel('Sentimento')
axs[0].set_ylabel('Contagem')

# Gráfico de barra para o DataFrame de treinamento.
axs[1].bar(train_sentiment_counts.index, train_sentiment_counts.values, color=['indianred', 'royalblue'])
axs[1].set_title('Distribuição de Sentimentos (Treinamento)')
axs[1].set_xlabel('Sentimento')
axs[1].set_ylabel('Contagem')

# Gráfico de barra para o DataFrame de teste.
axs[2].bar(test_sentiment_counts.index, test_sentiment_counts.values, color=['royalblue', 'indianred'])
axs[2].set_title('Distribuição de Sentimentos (Teste)')
axs[2].set_xlabel('Sentimento')
axs[2].set_ylabel('Contagem')

# Mostra os gráficos.
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.2 Treinamento
#
# Nessa etapa vamos apresentar os dados de treinamento para o algoritmo escolhido (DecisionTreeClassifier).

# %%
# Importa a biblioteca nltk (Natural Language Toolkit) para processamento de texto.
import nltk
# Baixa os dados necessários para o tokenizer, que divide o texto em palavras.
nltk.download('punkt')

# Importa o classificador DecisionTreeClassifier da scikit-learn
from sklearn.tree import DecisionTreeClassifier

# Importa a biblioteca para vetorização
from sklearn.feature_extraction.text import CountVectorizer

# Prepara os dados de treinamento e teste
X_train = train_df['Frase']
y_train = train_df['Sentimento']
X_test = test_df['Frase']
y_test = test_df['Sentimento']

# Vetoriza o texto usando a contagem de palavras (CountVectorizer)
vectorizer = CountVectorizer()
X_train_vectorized = vectorizer.fit_transform(X_train)
X_test_vectorized = vectorizer.transform(X_test)

# Cria o modelo de árvore de decisão
clf = DecisionTreeClassifier(random_state=42)

# Treina o modelo
clf.fit(X_train_vectorized, y_train)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# ### 2.3 Avaliação
#
# A matriz de confusão é uma ferramenta fundamental na avaliação de modelos de classificação. Ela fornece uma visão detalhada do desempenho do modelo, mostrando como suas previsões se comparam com os valores reais do conjunto de dados. A matriz de confusão é geralmente organizada em quatro quadrantes, e cada elemento da matriz representa uma contagem de instâncias:
#
# - **Verdadeiros Positivos (True Positives - TP):** São os casos em que o modelo fez uma previsão correta, identificando corretamente uma instância como pertencente à classe positiva, e essa instância realmente pertence à classe positiva. Por exemplo, quando o modelo previu que a frase é do rotulo "gostei" e de fato a frase pertence a essa categoria.
#
# - **Falsos Negativos (False Negatives - FN):** São os casos em que o modelo errou ao prever que uma instância pertence à classe negativa, quando na verdade a instância pertence à classe positiva. Por exemplo, quando o modelo previu que a frase pertence a classe "não gostei" e na verdade a frase pertence a categoria "gostei".
#
# - **Falsos Positivos (False Positives - FP):** São os casos em que o modelo errou ao prever que uma instância pertence à classe positiva, quando na verdade a instância pertence à classe negativa. Por exemplo, quando o modelo previu que a frase pertence a classe "gostei" e na verdade a frase pertence a categoria "não gostei".
#
# - **Verdadeiros Negativos (True Negatives - TN):** São os casos em que o modelo fez uma previsão correta, identificando corretamente uma instância como pertencente à classe negativa, e essa instância realmente pertence à classe negativa. Por exemplo, quando o modelo previu que a frase é do rotulo "não gostei" e de fato a frase pertence a essa categoria.

# %%
# Importa funções para avaliação de modelos de classificação, como classification_report e confusion_matrix.
from sklearn.metrics import confusion_matrix

# Importa as bibliotecas seaborn e matplotlib.pyplot para visualização de dados.
import seaborn as sns
import matplotlib.pyplot as plt

# Previsões
y_test_predict = clf.predict(X_test_vectorized)

# Matriz de Confusão com Seaborn
confusion = confusion_matrix(y_test, y_test_predict)
labels = ['gostei', 'não gostei']

plt.figure(figsize=(8, 4))
sns.heatmap(confusion, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.title('Matriz de Confusão')
plt.show()

# %% [markdown]
# #### 2.3.1 Métricas
#
# Nessa etapa vamos submeter as frase do dataframe de teste e pedir para o modelo treinado predizer os sentimentos. Vamos comparar a predição com os sentimentos reais para calcular as métricas de presicion, de recall e f-measure.
#
# - **Precisão (Precision):**
#
# A precisão mede a proporção de previsões corretas (verdadeiros positivos) em relação ao total de previsões positivas feitas pelo modelo (verdadeiros positivos mais falsos positivos). A precisão é importante quando queremos minimizar os falsos positivos.
#
# - **Revocação (Recall):**
#
# A revocação mede a proporção de previsões corretas (verdadeiros positivos) em relação ao total de amostras que realmente pertencem à classe positiva (verdadeiros positivos mais falsos negativos). A revocação é relevante quando é fundamental identificar todas as instâncias positivas, minimizando assim os falsos negativos.
#
# - **F1-Score (F-measure):**
#
# O F1-Score é a média harmônica entre a precisão e a revocação. Ele combina ambas as métricas em uma única medida, dando mais peso à menor delas. O F1-Score é útil quando você deseja encontrar um equilíbrio entre precisão e revocação. Ele é especialmente útil quando as classes estão desequilibradas, pois evita que o desempenho seja dominado por uma das métricas.
#
# - **Acurácia (Accuracy):**
#
# A acurácia mede a proporção de previsões corretas em relação ao total de previsões feitas pelo modelo. A acurácia é uma métrica geral que indica o quão bem o modelo está performando no geral. No entanto, pode ser enganosa em cenários com classes desequilibradas, onde um alto número de amostras pertence a uma classe e poucas pertencem à outra.

# %%
# Importa funções para avaliação de modelos de classificação, como classification_report e confusion_matrix.
from sklearn.metrics import classification_report

print('Relatório de Classificação:')
print(classification_report(y_test, y_test_predict))
# Out:
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#       gostei       0.89      0.73      0.80        11
#   não gostei       0.50      0.75      0.60         4
#
#     accuracy                           0.73        15
#    macro avg       0.69      0.74      0.70        15
# weighted avg       0.79      0.73      0.75        15

# %% [markdown]
# #### 2.3.2 Possíveis problemas
#
#
# ![ciclo](https://drive.google.com/uc?id=1JMnC-ZDK4z3Brjji3mLaBot-_mZhnH-1)
#
#
# - **Underfitting:**
#
# Se o modelo tiver um desempenho ruim nos dados de treinamento (baixa precisão, baixo recall, alta taxa de erro, etc.) e também tiver um desempenho ruim nos dados de teste, é um sinal de underfitting. Isso indica que o modelo é muito simples para capturar a complexidade dos dados.
#
#
# - **Overfitting:**
#
# Alto desempenho nos dados de treinamento e baixo desempenho nos dados de teste podem ser um sinal clássico de overfitting. É quando o modelo tem um desempenho muito bom nos dados de treinamento, mas um desempenho significativamente pior nos dados de teste. O modelo "decorou" os dados de treinamento, mas não consegue generalizar bem para novos dados.

# %% [markdown]
# #### 2.3.3 Validação Cruzada
#
# ![validacao-cruzada](https://drive.google.com/uc?id=1IrduxBqHhfjHXYaDmMCeg7T6H-jD5_Xm)
#
# A validação cruzada é uma técnica para avaliar a capacidade de generalização de um modelo, a partir de um conjunto de dados. Esta técnica é amplamente empregada em problemas onde o objetivo da modelagem é a predição. Busca-se então estimar o quão preciso é este modelo na prática, ou seja, o seu desempenho para um novo conjunto de dados.

# %% [markdown]
# # 3. Implementação Deep Learning
#
# O Deep Learning (rede neural profunda) é uma subárea da aprendizagem de máquina (Machine Learning) que se concentra no treinamento de redes neurais profundas, ou seja, redes neurais com várias camadas.
#
# ![deeplearning](https://drive.google.com/uc?id=1ZlwEPnCnz04r0Q9o0yl22_7JeIXLVE1y)

# %% [markdown]
# ### 3.1 Perceptron
#
# O perceptron é um **modelo linear de classificação binária** que requer que os dados sejam **linearmente separáveis** para funcionar adequadamente. Ele aprende por meio do cálculo de pesos e vieses e foi inspirado no funcionamento do neurônio humano. Proposto em 1943 por McCulloch e Pitt negritos e implementado em 1958 por Frank Rosenblatt, o perceptron foi inicialmente considerado um passo importante em direção à criação de um computador eletrônico com habilidades avançadas, como andar, falar, ver e ter consciência.
#
# ![deeplearning](https://drive.google.com/uc?id=1o4DN3KB8KvGOh-8kwzvI02KnsyR3_jFb)
#
# Os pesos são atualizados com base no algoritmo de aprendizagem de descida gradiente (gradient descent learning algorithm). Ou seja, os pesos são atualizados de acordo com o feedback do resultado da função de ativação, que é uma função de degrau unitário. Segue a formula:
#
# ![deeplearning](https://drive.google.com/uc?id=1YiqaNT7iYyRWvJjHnYC7OB0vHVAU9Mrb)
#
# Segue a implementação de uma classe com as principais funções de um Perceptron.
#
# Link com detalhamento da implementação: https://vitalflux.com/perceptron-explained-using-python-example/amp/.

# %%
import numpy as np

# Definição da classe Perceptron
class CustomPerceptron(object):

    # Construtor passando quantidade de iteração, estado aleatório e taxa de aprendizagem
    def __init__(self, n_iterations=100, random_state=1, learning_rate=0.01):
        self.n_iterations = n_iterations
        self.random_state = random_state
        self.learning_rate = learning_rate


    # Função de treinamento
    # 1. Os pesos são alterados baseado em cada exemplo de treinamento
    # 2. O aprendizado dos pesos continua por multiplas iterações
    # 3. A taxa de aprendizagem precisa ser definida
    def fit(self, X, y):
        rgen = np.random.RandomState(self.random_state)
        self.coef_ = rgen.normal(loc=0.0, scale=0.01, size=1 + X.shape[1])
        self.errors_ = []
        for _ in range(self.n_iterations):
            errors = 0
            for xi, expected_value in zip(X, y):
                predicted_value = self.predict(xi)
                self.coef_[1:] = self.coef_[1:] + self.learning_rate * (expected_value - predicted_value) * xi
                self.coef_[0] = self.coef_[0] + self.learning_rate * (expected_value - predicted_value) * 1
                update = self.learning_rate * (expected_value - predicted_value)
                errors += int(update != 0.0)
            self.errors_.append(errors)

    # Função responsável por realizar a soma ponderada dos pesos
    def net_input(self, X):
        # Inicializa a soma ponderada com o peso de viés (coef_[0])
        weighted_sum = self.coef_[0]
        # Multiplica os valores de entrada pelos pesos correspondentes e soma
        weighted_sum += np.sum(X * self.coef_[1:])
        return weighted_sum

    # Método responsável por executar a função de ativação
    def activation_function(self, X):
        weighted_sum = self.net_input(X)
        return np.where(weighted_sum >= 0.0, 1, 0)

    # Função responsável por prever através ds função de ativação
    def predict(self, X):
        return self.activation_function(X)

    # Função que calcula a acurácia comparando o resultado esperado com o resultado previsto
    def score(self, X, y):
        misclassified_data_count = 0
        for xi, target in zip(X, y):
            output = self.predict(xi)
            if(target != output):
                misclassified_data_count += 1
        total_data_count = len(X)
        self.score_ = (total_data_count - misclassified_data_count)/total_data_count
        return self.score_

# %% [markdown]
# Para testar a implementação do perceptron utilizaremos o Iris Dataset do pacote SckitLearn, que contém informações sobre 4 características de 3 espécies de plantas Iris e 150 amostras, 50 de cada. Entretanto, nós usaremos apenas 2 características (comprimento e largura das petálas) e 2 espécies de plantas (setosa e versicolor).
#
# ![deeplearning](https://drive.google.com/uc?id=1eUxUI6S1SHep9Za1EzvqDHOwrAtOoZQ5)

# %%
# Importando o dataset iris
from sklearn.datasets import load_iris

# Determinando o X e y
X_iris,y_iris = load_iris(return_X_y=True, as_frame=True)

# Selecionando apenas as colunas de pétala e o target 0 e 1 das flores versicolor e setosa
X = X_iris.loc[y_iris.isin([0,1]),['petal length (cm)','petal width (cm)']]
y = y_iris.loc[y_iris.isin([0,1])]

# %%
import matplotlib.pyplot as plt

# Observando graficamente os dados
fig, ax = plt.subplots()

ax.scatter(X.iloc[:50,0],X.iloc[:50,1], c="red", label="iris-setosa")
ax.scatter(X.iloc[50:100,0],X.iloc[50:100,1], c="blue", label="iris-versicolor")

ax.set(xlim=(0.9,5.2),xticks=[1,2,3,4,5],
   ylim=(0,2),yticks=[0,1,2])

ax.set_xlabel("Tamanho da pétala (cm)")
ax.set_ylabel("Largura da pétala (cm)")
ax.legend(loc="upper left")

plt.show()

# %%
from sklearn.model_selection import train_test_split

# Dividindo o dado em 70% treinamento e 30% teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Instanceando CustomPerceptron
prcptrn = CustomPerceptron(n_iterations=5)

# Treinando o modelo
prcptrn.fit(X_train.values, y_train)

# Avaliando
print('Acurácia do teste: %.3f' % prcptrn.score(X_test.values, y_test))
print('Acurácia do treinamento: %.3f' % prcptrn.score(X_train.values, y_train))
# Out:
# Acurácia do teste: 1.000
# Acurácia do treinamento: 1.000

# %% [markdown]
# É fundamental que tenhamos o entendimento sobre o funcionamento do Perceptron, pois ele é a base para as redes neurais. Porém em Python muitas das implementações elementares já existem e não precisamos reinventar a roda. Segue uma implementação utilizando Perceptron do pacote SckitLearn, simplificando toda essa nossa implementação anterior.

# %%
from sklearn.linear_model import Perceptron
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

ppn = Perceptron(eta0=0.1, random_state=1)
ppn.fit(X_train_std, y_train)

y_pred = ppn.predict(X_test_std)

print('Acurácia do metrics: %.3f' % accuracy_score(y_test, y_pred))
print('Acurácia implementada no perceptron: %.3f' % ppn.score(X_test_std, y_test))
# Out:
# Acurácia do metrics: 1.000
# Acurácia implementada no perceptron: 1.000

# %% [markdown]
# ### 3.2 Convolutional Neural Networks (CNNs)
#
# As Convolutional Neural Networks (CNNs) são um tipo de rede neural profunda que foi projetada especificamente para tarefas de visão computacional, como processamento de imagens e vídeos. As CNNs estão intrinsecamente ligadas ao campo do Deep Learning, e podem ser consideradas uma das arquiteturas mais importantes e influentes dentro desse campo. Dentro de uma Convolutional Neural Network (CNN), as "learned features" (características aprendidas) referem-se às representações de características extraídas automaticamente das imagens durante o processo de treinamento da rede. Essas características aprendidas são um dos aspectos mais poderosos e distintivos das CNNs e desempenham um papel fundamental em sua capacidade de realizar tarefas de visão computacional com alto desempenho.
#
# ![cnn](https://drive.google.com/uc?id=1wd64fLsLbPmhySKN3d5SipruAmGWwb99)
#
# Agora vamos resolver um problema mais complexo, utilizando as ferramentas do tensorflow para criar redes mais robustas.

# %% [markdown]
# #### 3.3.1 Entendimento do problema
#
# ![kaggle](https://drive.google.com/uc?id=1GcTzwgXJO5JLW8fxqMxWfRuGZNKxNf27)
#
# O Kaggle é uma plataforma de ciência de dados e aprendizado de máquina que oferece competições, datasets, notebooks, cursos, e uma comunidade ativa. É conhecido por desafios de análise de dados da vida real, onde os participantes criam modelos preditivos. Além disso, oferece recursos educacionais, tutoriais e integração de dados através de uma API. Também é usado por empresas para recrutamento de talentos em ciência de dados e realiza eventos presenciais chamados Kaggle Days. O Kaggle é uma ferramenta valiosa para profissionais e entusiastas da análise de dados.
#
# Os dados são o ativo mais valioso para a ciência de dados, existem alguns datasets públicos disponíveis para uso geral:
#
# https://paperswithcode.com/datasets
#
# https://www.kaggle.com/datasets
#
# https://scikit-learn.org/stable/datasets.html

# %% [markdown]
# Para o nosso exemplo implementaremos uma CNN capaz de identificar se a imagem refere-se a um gato ou a um cachorro. O dataset e os detalhes do problema estão disponíveis aqui: https://www.kaggle.com/c/dogs-vs-cats/overview
#
# ![catdog](https://drive.google.com/uc?id=1nQy-_4MuKqjV6Q6_s-5DR4Bd53SN0Qku)

# %% [markdown]
# ##### **Preparação os dados**
#
# Nessa seção realizaremos:
#
# *   download das imagens compactadas
# *   descompataremos as imagens
# *   organizaremos as imagens em diretórios

# %%
# Realizar o download do Dataset (852 MB)
# !gdown 1YSKeUiJ-7_X0SdwjgyiZNXiDCoc7cPlF
# Out:
# Failed to retrieve file url:
#
# 	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
# 	Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1YSKeUiJ-7_X0SdwjgyiZNXiDCoc7cPlF
#
# but Gdown can't. Please check connections and permissions.

# %%
# Descompactando o arquivo dogs-vs-cats.zip
# !unzip -q dogs-vs-cats.zip

# Descompactando o arquivo train.zip
# !unzip train.zip
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#   inflating: train/dog.5499.jpg
#   inflating: train/dog.55.jpg
#   inflating: train/dog.550.jpg
#   inflating: train/dog.5500.jpg
#   inflating: train/dog.5501.jpg
#   inflating: train/dog.5502.jpg
#   inflating: train/dog.5503.jpg
#   inflating: train/dog.5504.jpg
#   inflating: train/dog.5505.jpg
#   inflating: train/dog.5506.jpg
#   inflating: train/dog.5507.jpg
#   inflating: train/dog.5508.jpg
#   inflating: train/dog.5509.jpg
#   inflating: train/dog.551.jpg
#   inflating: train/dog.5510.jpg
#   inflating: train/dog.5511.jpg
#   inflating: train/dog.5512.jpg
#   inflating: train/dog.5513.jpg
#   inflating: train/dog.5514.jpg
#   inflating: train/dog.5515.jpg
#   inflating: train/dog.5516.jpg
#   inflating: train/dog.5517.jpg
#   inflating: train/dog.5518.jpg
#   inflating: train/dog.5519.jpg
#   inflating: train/dog.552.jpg
#   inflating: train/dog.5520.jpg
#   inflating: train/dog.5521.jpg
# ...

# %%
import os

# Define o diretório onde estão localizados os arquivos de imagem.
data_dir = '/content/train'

# Inicializa contadores para contar o número de arquivos que começam com "dog" e "cat".
dog_count = 0
cat_count = 0

# Itera sobre os arquivos no diretório especificado.
for filename in os.listdir(data_dir):
    # Verifica se o nome do arquivo começa com "dog".
    if filename.startswith("dog"):
        dog_count += 1  # Incrementa o contador de arquivos "dog".
    # Verifica se o nome do arquivo começa com "cat".
    elif filename.startswith("cat"):
        cat_count += 1  # Incrementa o contador de arquivos "cat".

# Imprime a quantidade de arquivos que começam com "dog" e "cat".
print(f"Quantidade de 'dog': {dog_count}")
print(f"Quantidade de 'cat': {cat_count}")
# Out:
# Quantidade de 'dog': 12500
# Quantidade de 'cat': 12500

# %%
import shutil

# Criação dos diretórios para armazenar imagens
os.mkdir('/content/PetImages')
os.mkdir('/content/PetImages/Cat')
os.mkdir('/content/PetImages/Dog')

# Gera nomes de arquivos para imagens de gatos
fnames = ['cat.{}.jpg'.format(i) for i in range(12500)]

# Loop para copiar imagens de gatos
for fname in fnames:
    src = os.path.join('/content/train', fname)  # Caminho de origem (diretório de treinamento)
    dst = os.path.join('/content/PetImages/Cat', fname)  # Caminho de destino (diretório de gatos)
    shutil.copyfile(src, dst)  # Copia o arquivo de origem para o destino

# Gera nomes de arquivos para imagens de cachorros
fnames = ['dog.{}.jpg'.format(i) for i in range(12500)]

# Loop para copiar imagens de cachorros
for fname in fnames:
    src = os.path.join('/content/train', fname)  # Caminho de origem (diretório de treinamento)
    dst = os.path.join('/content/PetImages/Dog', fname)  # Caminho de destino (diretório de cachorros)
    shutil.copyfile(src, dst)  # Copia o arquivo de origem para o destino

# %%
import tensorflow as tf
from tensorflow import keras

# Define o tamanho desejado para as imagens e o tamanho do lote para carregamento durante o treinamento.
image_size = (180, 180)
batch_size = 16

# Cria um conjunto de dados de treinamento usando imagens do diretório "PetImages".
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "PetImages",
    validation_split=0.2,  # Divide automaticamente 20% das imagens para validação.
    subset="training",      # Indica que este é o conjunto de treinamento.
    seed=1337,              # Define uma semente para reprodutibilidade.
    image_size=image_size,  # Define o tamanho desejado para as imagens.
    batch_size=batch_size   # Define o tamanho do lote para treinamento em mini lotes.
)

# Cria um conjunto de dados de validação usando imagens do diretório "PetImages".
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "PetImages",
    validation_split=0.2,  # Mesma divisão de validação usada no conjunto de treinamento.
    subset="validation",    # Indica que este é o conjunto de validação.
    seed=1337,              # Mesma semente usada para reprodutibilidade.
    image_size=image_size,  # Mesmo tamanho desejado para as imagens.
    batch_size=batch_size   # Mesmo tamanho do lote usado no conjunto de treinamento.
)
# Out:
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.
# Found 25000 files belonging to 2 classes.
# Using 5000 files for validation.

# %%
# Cria uma sequência de transformações de aumento de dados usando TensorFlow e Keras.
data_augmentation = keras.Sequential(
    [
        # Camada que aplica uma virada horizontal aleatória nas imagens.
        tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal"),

        # Camada que aplica uma rotação aleatória com ângulo máximo de 0.1 radianos.
        tf.keras.layers.experimental.preprocessing.RandomRotation(0.1),
    ]
)

# %% [markdown]
# ##### **Visualização**

# %%
# Importa a biblioteca Matplotlib para plotagem de gráficos.
import matplotlib.pyplot as plt

# Cria uma figura de plotagem com tamanho 10x10 polegadas.
plt.figure(figsize=(10, 10))

# Itera pelo primeiro lote (batch) de imagens e rótulos no conjunto de dados de treinamento.
for images, labels in train_ds.take(1):
    # Itera por 16 imagens no primeiro lote.
    for i in range(16):
        # Cria um subplot de 4x4 na figura.
        ax = plt.subplot(4, 4, i + 1)

        # Exibe a imagem atual (convertida para o tipo "uint8").
        plt.imshow(images[i].numpy().astype("uint8"))

        # Define o título do subplot com o rótulo da imagem (cast para int).
        plt.title(int(labels[i]))

        # Remove as informações dos eixos (axis) para uma exibição mais limpa.
        plt.axis("off")

# %%
# Cria uma figura de plotagem com tamanho de 10x10 polegadas.
plt.figure(figsize=(10, 10))

# Itera pelos dois primeiros lotes de imagens no conjunto de dados de treinamento (train_ds).
for images, _ in train_ds.take(2):
    # Itera por 9 vezes (nove vezes para cada lote de imagens).
    for i in range(9):
        # Aplica transformações de aumento de dados (data augmentation) nas imagens.
        augmented_images = data_augmentation(images)

        # Cria um subplot de 3x3 na figura.
        ax = plt.subplot(3, 3, i + 1)

        # Exibe a primeira imagem do lote após a aplicação das transformações (convertida para o tipo "uint8").
        plt.imshow(augmented_images[0].numpy().astype("uint8"))

        # Remove as informações dos eixos (axis) para uma exibição mais limpa.
        plt.axis("off")

# %% [markdown]
# ##### **Modelagem**
#
# O pré-carregamento (prefetching) é uma técnica que permite que os dados sejam carregados de forma eficiente em lotes antecipadamente durante o treinamento ou validação, enquanto o modelo está ocupado processando o lote atual. Isso ajuda a melhorar o desempenho do treinamento e validação, pois reduz o tempo de espera para carregar dados no momento em que são necessários, mantendo a CPU ou GPU ocupada com o processamento.

# %%
# Prefetching (Pré-carregamento) é uma técnica usada para otimizar a velocidade de treinamento do modelo.

# Prefetch do conjunto de dados de treinamento (train_ds) para acelerar o treinamento.
train_ds = train_ds.prefetch(buffer_size=32)

# Prefetch do conjunto de dados de validação (val_ds) para acelerar o processo de validação.
val_ds = val_ds.prefetch(buffer_size=32)

# %%
# Função para criar o modelo de rede neural.
def make_model(input_shape, num_classes):
    # Define a camada de entrada com a forma especificada (input_shape).
    inputs = keras.Input(shape=input_shape)

    # Bloco de aumento de dados de imagem.
    x = data_augmentation(inputs)

    # Bloco de pré-processamento de entrada (normalização de pixels).
    x = tf.keras.layers.experimental.preprocessing.Rescaling(1.0 / 255)(x)

    # Camada de convolução 2D com 32 filtros, tamanho do filtro 3x3, passo de 2 e valid padding.
    x = tf.keras.layers.Conv2D(32, 3, strides=2, padding="valid")(x)
    x = tf.keras.layers.BatchNormalization()(x)  # Normalização por lotes.
    x = tf.keras.layers.Activation("relu")(x)    # Função de ativação ReLU.
    x = tf.keras.layers.MaxPooling2D(2, strides=2, padding="valid")(x)  # Camada de pooling.

    # Camada de convolução 2D com 64 filtros e tamanho do filtro 3x3.
    x = tf.keras.layers.Conv2D(64, 3, padding="valid")(x)
    x = tf.keras.layers.BatchNormalization()(x)  # Normalização por lotes.
    x = tf.keras.layers.Activation("relu")(x)    # Função de ativação ReLU.
    x = tf.keras.layers.MaxPooling2D(2, strides=2, padding="valid")(x)  # Camada de pooling.

    # Camada de convolução 2D com 128 filtros e tamanho do filtro 3x3.
    x = tf.keras.layers.Conv2D(128, 3, padding="valid")(x)
    x = tf.keras.layers.BatchNormalization()(x)  # Normalização por lotes.
    x = tf.keras.layers.Activation("relu")(x)    # Função de ativação ReLU.
    x = tf.keras.layers.MaxPooling2D(2, strides=2, padding="valid")(x)  # Camada de pooling.

    # Achatamento das características extraídas.
    x = tf.keras.layers.Flatten()(x)

    # Camada oculta (hidden layer) com 128 unidades e ativação ReLU.
    x = tf.keras.layers.Dense(128, activation='relu')(x)

    # Camada de saída com uma única unidade e ativação sigmoid para classificação binária.
    outputs = tf.keras.layers.Dense(1, activation="sigmoid")(x)

    # Cria o modelo final com as camadas definidas.
    return keras.Model(inputs, outputs)

# Criação do modelo com as dimensões de entrada especificadas e 2 classes de saída.
model = make_model(input_shape=image_size + (3,), num_classes=2)

# Mostra o resumo do modelo
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  sequential (Sequential)     (None, 180, 180, 3)       0
#
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 89, 89, 32)        896
#
#  batch_normalization (Batch  (None, 89, 89, 32)        128
#  Normalization)
#
#  activation (Activation)     (None, 89, 89, 32)        0
#
#  max_pooling2d (MaxPooling2  (None, 44, 44, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 42, 42, 64)        18496
#
#  batch_normalization_1 (Bat  (None, 42, 42, 64)        256
#  chNormalization)
#
#  activation_1 (Activation)   (None, 42, 42, 64)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 21, 21, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 19, 19, 128)       73856
#
# ...

# %% [markdown]
# ##### **Treinamento**

# %%
# Define o número de épocas (ciclos de treinamento) desejado.
epochs = 20

# Compilação do modelo com otimizador Adam, função de perda "binary_crossentropy" e métrica "accuracy".
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),      # Otimizador Adam com taxa de aprendizado de 0,001.
    loss="binary_crossentropy",                 # Função de perda para classificação binária.
    metrics=["accuracy"]                        # Métrica de acurácia para avaliar o desempenho do modelo.
)

# Treinamento do modelo usando os dados de treinamento (train_ds) e validação (val_ds).
history_1 = model.fit(
    train_ds,                                   # Conjunto de treinamento.
    epochs=epochs,                             # Número de épocas.
    validation_data=val_ds,                    # Dados de validação.
    verbose=1,                                 # Exibe informações durante o treinamento.
)
# Out:
# Epoch 1/20
# 1250/1250 [==============================] - 49s 29ms/step - loss: 0.6506 - accuracy: 0.6668 - val_loss: 0.5955 - val_accuracy: 0.6736
# Epoch 2/20
# 1250/1250 [==============================] - 44s 35ms/step - loss: 0.4944 - accuracy: 0.7574 - val_loss: 0.4589 - val_accuracy: 0.7764
# Epoch 3/20
# 1250/1250 [==============================] - 35s 28ms/step - loss: 0.4415 - accuracy: 0.7898 - val_loss: 0.5750 - val_accuracy: 0.7272
# Epoch 4/20
# 1250/1250 [==============================] - 33s 27ms/step - loss: 0.4074 - accuracy: 0.8138 - val_loss: 0.4525 - val_accuracy: 0.7912
# Epoch 5/20
# 1250/1250 [==============================] - 38s 30ms/step - loss: 0.3765 - accuracy: 0.8315 - val_loss: 0.7040 - val_accuracy: 0.6896
# Epoch 6/20
# 1250/1250 [==============================] - 34s 27ms/step - loss: 0.3510 - accuracy: 0.8417 - val_loss: 0.3399 - val_accuracy: 0.8548
# Epoch 7/20
# ...

# %% [markdown]
# ##### **Acurácia e perda**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")

# Crie uma figura com duas subtramas (um para perda e outro para precisão).
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 6))

# Gráfico de linha para perda (loss).
sns.lineplot(x=range(1, epochs+1), y=history_1.history['loss'], color='b', label="Training loss", ax=ax1)
sns.lineplot(x=range(1, epochs+1), y=history_1.history['val_loss'], color='r', label="Validation loss", ax=ax1)
ax1.set_xticks(range(1, epochs+1))
ax1.set_yticks(np.arange(0, 1, 0.1))
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.set_title('Training and Validation Loss')

# Gráfico de linha para precisão (accuracy).
sns.lineplot(x=range(1, epochs+1), y=history_1.history['accuracy'], color='b', label="Training accuracy", ax=ax2)
sns.lineplot(x=range(1, epochs+1), y=history_1.history['val_accuracy'], color='r', label="Validation accuracy", ax=ax2)
ax2.set_xticks(range(1, epochs+1))
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.set_title('Training and Validation Accuracy')

# Adicione uma legenda.
legend = plt.legend(loc='best', shadow=True)

# Ajuste o layout e exiba o gráfico.
plt.tight_layout()
plt.show()
